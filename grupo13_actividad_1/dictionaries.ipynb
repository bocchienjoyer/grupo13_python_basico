# %% [markdown]
# # **Assignment 1 - Dictionaries**
#
# ### Responsable: Lory Acosta

# %%
population = {"Lima": 10092000, "Arequipa": 1008000, "Trujillo": 919000}
population
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Trujillo': 919000}

# %%
population.keys()
# Out:
# dict_keys(['Lima', 'Arequipa', 'Trujillo'])

# %%
population.get('Lima')
# Out:
# 10092000

# %%
population["Cusco"] = 428000

# %%
population.pop("Trujillo")
# Out:
# 919000

# %%
population
# Out:
# {'Lima': 10092000, 'Arequipa': 1008000, 'Cusco': 428000}
